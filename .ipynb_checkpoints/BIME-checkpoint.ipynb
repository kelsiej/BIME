# %%
import pandas as pd
import glob
import os 
import re

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', 60)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\workworkwork\\Documents\\school\\BIME'

# %%
cwd = os.getcwd()
events = []
os.chdir(cwd + '\\notes')
events = []
#convert all txt files in cwd to df, append to events, then concatenate
for file in glob.glob("*.txt"):
    data = pd.read_csv(file, encoding ='latin1')
    events.append(data)
events = pd.concat(events)
events = events.reset_index()

# %%
events.sample(3)
# Out:
#       index  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ELEMID                CHARTTIME  \
# 3214     18        8481  13331.0     10542.0     NaN  3298-12-21 00:00:00 EST
# 4965     35        8835   3119.0     10989.0     0.0  3116-04-03 05:21:00 EST
# 2456    146        8370   4174.0     10407.0     0.0  3108-06-02 14:52:00 EST
#
#                      REALTIME    CGID CORRECTION  CUID          CATEGORY  \
# 3214                      NaN     NaN        NaN   NaN  RADIOLOGY_REPORT
# 4965  3116-04-03 05:32:00 EST  3601.0          N  54.0     Nursing/Other
# 2456  3108-06-02 14:58:00 EST  2788.0          N  69.0     Nursing/Other
#
#      TITLE                                                         TEXT  \
# 3214   NaN  \r\n\r\n\r\n     DATE: [**3298-12-21**] 12:20 PM\r\n    ...
# 4965   NaN  \r\n\r\nPersistent [**Female First Name (un) **]\r\n\r\n...
# 2456   NaN  \r\n\r\ntransfered to the unit with septic shock and pna...
#
#       EXAM_NAME  PATIENT_INFO
# 3214        NaN           NaN
# 4965        NaN           NaN
# 2456        NaN           NaN

# %%
events.columns
# Out:
# Index(['index', 'SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID', 'ELEMID', 'CHARTTIME',
#        'REALTIME', 'CGID', 'CORRECTION', 'CUID', 'CATEGORY', 'TITLE', 'TEXT',
#        'EXAM_NAME', 'PATIENT_INFO'],
#       dtype='object')

# %% [raw]
# for i in range(len(events)):
#     print(events.SUBJECT_ID.loc[i])
#     print()
#     print(codecs.decode(events.TEXT.loc[i], 'unicode_escape'))

# %% [raw]
# # will use 8192
# df_8192 = events.loc[events.SUBJECT_ID.isin([8192])]
# df_8192 = df_8192.reset_index()
#
# for i in range(len(df_8192)):
#     print(codecs.decode(df_8192.TEXT.loc[i], 'unicode_escape'))

# %%
discharge = events.loc[events.CATEGORY == 'DISCHARGE_SUMMARY'].TEXT.tolist()
for i in range(len(discharge)):
    discharge[i] = discharge[i].replace('\n','newline').replace('\r',' ')

# %%
diagnosis_raw = []
for i in discharge:
    if re.search(r'DISCHARGE DIAGNOSES(.*?)DISCHARGE CONDITION', i, re.IGNORECASE):
        diagnosis_raw.append(re.search(r'DISCHARGE DIAGNOSES(.*?)DISCHARGE CONDITION', i, re.IGNORECASE).group(1))
    if re.search(r'DISCHARGE DIAGNOSiS(.*?)DISCHARGE CONDITION', i, re.IGNORECASE):
        diagnosis_raw.append(re.search(r'DISCHARGE DIAGNOSiS(.*?)DISCHARGE CONDITION', i, re.IGNORECASE).group(1))

# %%
diagnosis = []
for j in diagnosis_raw:
    
    start = []
    end = []
    for m in re.finditer('newline', j):
        start.append(m.start())
        end.append(m.end())
        
    diagnosis_ind = []
    for i in range(len(start)-1):
        diagnosis_ind.append((j[end[i]:start[i+1]]))
        
    diagnosis.append(diagnosis_ind)

# %%
#some issue I can't figure out, should be a simpler way to do the previous cell
#but skips every other new line :(
re.findall(r'newline(.*?)newline', diagnosis_raw[1])
# Out:
# ['MRSA bacteremia ',
#  '1. Small cell lung cancer status post Cisplatin in [**2515**] and  ',
#  '2. Chronic obstructive pulmonary disease.  ',
#  '4. Hypertension.  ',
#  '6. Anemia.  ',
#  '8. Neuropathy  ',
#  '  ']

# %%
dia = diagnosis

# %%
for i in range(len(diagnosis)):
    for j in range(len(diagnosis[i])):
        diagnosis[i][j] = diagnosis[i][j].replace('1. ','').replace('2. ','').replace('3. ','').replace('4. ','')\
        .replace('5. ','').replace('6. ','').replace('7. ','').replace('8. ','').replace('9. ','')\
        .replace('10. ','').replace('11. ','')

# %%
for i in range(len(diagnosis)):

    diagnosis[i] = [x.lower() for x in diagnosis[i]]

# %%
for i in range(len(diagnosis)):
    if 'secondary: ' in diagnosis[i]:
        diagnosis[i].remove('secondary: ')  
    if 'primary: ' in diagnosis[i]:
        diagnosis[i].remove('primary: ')      
    if 'primary diagnosis: ' in diagnosis[i]:
        diagnosis[i].remove('primary diagnosis: ')      
    if 'primary diagnoses: ' in diagnosis[i]:
        diagnosis[i].remove('primary diagnoses: ')
    if 'secondary diagnosis: ' in diagnosis[i]:
        diagnosis[i].remove('secondary diagnosis: ')  
    if 'secondary diagnoses: ' in diagnosis[i]:
        diagnosis[i].remove('secondary diagnoses: ')
    if ', ' in diagnosis[i]:
        diagnosis[i].remove(', ')  
    if ' ' in diagnosis[i]:
        diagnosis[i].remove(' ')  
    if '  ' in diagnosis[i]:
        diagnosis[i].remove('  ')

# %%
#needs further cleaning
#issue: one diagnoses is sometimes on multiple lines
diagnosis
# Out:
# [['left foot gangrene ',
#   'urosepsis ',
#   'a-fibrillation ',
#   'esrd/hd ',
#   'diabetes type 2 with triopathy ',
#   'mrsa ',
#   'depression ',
#   'glaucoma '],
#  ['mrsa bacteremia ',
#   'pseudomonal lung infection ',
#   'small cell lung cancer status post cisplatin in [**2515**] and  ',
#   'bt16 that was complicated by peripheral neuropathy.  ',
#   'chronic obstructive pulmonary disease.  ',
#   'paroxysmal atrial fibrillation.  ',
#   'hypertension.  ',
#   'hypothyroidism.  ',
#   'anemia.  ',
#   'non-melanoma skin cancer.  ',
#   'neuropathy  '],
#  ['death '],
#  ['ventricular fibrillation leading to severe anoxic brain injury. '],
#  ['thoracic aortic aneurysm - s/p endovascular stent, postop  ',
#   'pneumonia(pseudomonas), chronic obstructive pulmonary disease,  ',
#   'emphysema, history of asbestosis versus mesotheilioma - s/p rul  ',
#   'lung resection, hypertension,  renal cell carcinoma - s/p  ',
#   'nephrectomy, depression '],
#  ['status post pancreaticoduodenectomy ',
#   'anoxic brain injury ',
#   'brain death ',
#   'aspiration pneumonia ',
#   'diabetes ',
#   'hypertension ',
#   'history of coronary artery disease ',
#   'blood loss anemia ',
#   'respiratory failure '],
#  ['expired on [**3184-3-26**]. '],
#  ['inoperable gastric stromal cancer '],
#  ['coronary artery disease ',
#   'myocardial infarction ',
#   'depression ',
#   'diabetes ',
#   'chronic back pain ',
#   'hypertension ',
#   'hypercholesterolemia '],
#  ['expired '],
#  ['gastrointestinal bleed ',
#   'urinary tract infection ',
#   'c difficile infection.  ',
#   'secondary.  ',
#   'alcoholic cirrhosis ',
#   'depression '],
#  ['chf ',
#   'pneumonia ',
#   'tachycardia of undetermined origin ',
#   'end stage renal disease ',
#   'htn ',
#   'dementia '],
#  [' status post delirium ',
#   ' mild dementia ',
#   ' severe emphysema ',
#   ' chronic pancreatitis ',
#   ' atrial fibrillation ',
#   ' heart failure ',
#   ' osteoporosis '],
#  ['diastolic heart failure. ',
#   'nstemi. ',
#   'acute embolic left frontal and right parietal stroke. ',
#   'acute renal failure ',
#   'chronic kidney disease stage v. ',
#   'peripheral vascular disease. ',
#   'bilateral bka. ',
#   'diabetes mellitus type ii. ',
#   'peripheral neuropathy. ',
#   's/p lue fistula [**2770-3-6**] '],
#  ['subdural hemorrhage, interparenchymal hemorrhage '],
#  ['pneumonia ',
#   '. ',
#   'restrictive lung disease ',
#   'hypertension ',
#   's/p pulmonary embolus ',
#   'glaucoma '],
#  ['metastatic breast ca ', 'hemoptysis ', 'gastric ulcer '],
#  ['-right mca territory ischemic stroke ',
#   '-grade i splenic laceration ',
#   '-presumed aspiration pneumonia ',
#   '-t12 wedge compression fracture ',
#   '-asymptomatic high-grade left internal carotid artery stenosis '],
#  ['chf ',
#   'respiratory failure ',
#   'acute renal failure ',
#   'delirium ',
#   'hypotension '],
#  ['lerft mca stroke '],
#  ['lower gastrointestinal bleed secondary to cecal ',
#   'polypectomy, status post colonoscopy and ',
#   'intervention/injection, cauterization of the bleeding lesion. ',
#   'hypertrophic cardiomyopathy. ',
#   'hypothyroidism. ',
#   'hypertension. ',
#   'hypercholesterolemia. ',
#   'prostate cancer status post turp x',
#   'mitral regurgitation. ',
#   'tricuspid regurgitation. ',
#   'diastolic dysfunction. '],
#  ['clostridium difficile colitis '],
#  ['esophageal cancer '],
#  ['diastolic congestive heart failure ',
#   'aortic stenosis ',
#   'mitral stenosis ',
#   'possible chronic obstructive lung disease ',
#   'coronary artery disease ',
#   'chronic kidney disease ',
#   'depression ',
#   'diabetes mellitus '],
#  ['primary diagnosis:  ',
#   'left hip fracture s/p orif w/ subsequent hematoma. ',
#   'nstemi.  ',
#   'systolic heart failure ef ~ 25%  ',
#   'atrial fibrillation.  ',
#   'lv apical thrombus.  ',
#   'generalized tonic-clonic seizure - left sided [**doctor last name 1210**]  ',
#   'paralysis.  ',
#   'aspiration pneumonia.  ',
#   'delirium.  ',
#   'malnutrition - moderate degree.  ',
#   'secondary:  ',
#   'dementia.  ',
#   'normal pressure hydrocephalus s/p vp shunt.  ',
#   'coronary artery disease s/p cabg  ',
#   'ischemic cardiomyopathy 4+ mitral regurgitation.  ',
#   '  '],
#  ['left intraparenchymal hemorrhage with associated subarachnoid  ',
#   'hemorrhage ',
#   'pneumonia  ',
#   'hypertension ',
#   'atrial fibrillation with rapid ventricular rate ',
#   'hypokalemia '],
#  ['ventricular tachycardia ',
#   'cardiac arrest ',
#   'fibrothorax ',
#   'respiratory failure ',
#   'hemodialysis line infection ',
#   'hospital acquired pneumonia ',
#   'end-stage renal failure ',
#   'congestive heart failure ',
#   'coronary artery disease ',
#   'peripheral vascular disease ',
#   'diabetes mellitus type 2 - controlled ',
#   'stroke ',
#   'atrial fibrillation '],
#  ['upper gastrointestinal bleeding ',
#   'hemorrhagic shock secondary to gi bleed ',
#   'cardiac demand ischemia secondary to gi bleed ',
#   'hypernatremia ',
#   'parotid abscesses ',
#   'uti ',
#   'left arm mrsa swab ',
#   '. ',
#   'secondary diagnoses ',
#   'htn ',
#   'chf ',
#   'copd '],
#  ['1) mva resulting in traumatic head injury with subarachnoid  ',
#   'hemorrhage, subdural hemorrhage, epidural hemorrhage, lacerated  ',
#   'superior sagittal sinus from depressed right-sided high  ',
#   'parietal/high frontal skull fracture crossing midline. ',
#   '        --s/p right-sided hemicraniectomy, evacuation of  ',
#   'hematoma, repair of sinus ',
#   '2) fevers - query drug hypersensitivity ',
#   '3) chemical pancreatitis (perhaps secondary to #2) ',
#   '4) transaminitis/hepatitis (perhaps secondary to #2) ',
#   '5) thrombocytosis - query secondary to #2 ',
#   '6) moderate malnutrition ',
#   '7) anemia of inflammation, no evidence for hemolysis, with some  ',
#   'mild blood loss - occult blood positive stools ',
#   '8) hypertension ',
#   '9) elevation of alpha-1-antitrypsin - query significance - would  ',
#   'repeat when acute inflammatory state subsides '],
#  ['non-small cell lung carcinoma ',
#   'massive hemoptysis ',
#   '. ',
#   'hairy cell leukemia ',
#   'prostate cancer '],
#  ['septic shock due to aspiration pneumonia ',
#   'e.coli bacteremia from aspiration pneumonia ',
#   'copd flare ',
#   'pancreatitis '],
#  ['pancreatitis/pancreatic abscess ',
#   'bilateral pleural effusions ',
#   'tongue mass ',
#   'pneumonia ',
#   'anemia of chronic disease '],
#  ['primary diagnoses.  ',
#   'heptic encephalopathy.  ',
#   'anemia  ',
#   'melena  ',
#   'varices of the esophagus.  ',
#   '.  ',
#   'secondary diagnoses:  ',
#   'cirrhosis [**12-30**] to hep c (on tx list)   ',
#   'osteopenia   ',
#   'reflex sympathetic dystrophy   ',
#   'pulmonary artery hypertension - not confirmed on most recent  ',
#   'echo.   ',
#   "mva in '[**80**] with head injury   "],
#  ['aortic occlusion ',
#   'axillary bifemoral bypass graft with ptfe ',
#   'ischemic colon ',
#   'respiratory failure ',
#   'cardiac arrest ',
#   'metabolic acidosis ',
#   'abdominal compartment syndrome ',
#   'pleural effusion ',
#   'shock ',
#   'aaa ',
#   'mesenteric ischemia ',
#   'exploratory laparotomy ',
#   'coagulopathy ',
#   'acute renal failure '],
#  ['biliateral supracondylar femural fractures, pneumonia, copd  ',
#   'exacerbation ',
#   'anemia ',
#   'severe copd(at baseline on home o2: 4l) , cad, osteoperosis,  ',
#   'chronic lower back pain, migraines, depression '],
#  ['-upper gastrointestinal bleed, likely from gastric varices ',
#   '-pancreatic cancer ',
#   '-hypertension ',
#   '-hypothyroidism ',
#   '-type 2 diabetes mellitus '],
#  ['primary diagnosis: esophageal and gastric variceal bleeding,  ',
#   'active substance abuse ',
#   'secondary diagnosis: patent tips, failed liver transplant,  ',
#   'hepatitis c cirrhosis, pancytopenia '],
#  ['non small cell lung cancer with metastatic disease to the brain ',
#   'hemoptysis from lung cancer '],
#  ['lower gi bleed ',
#   '---- ',
#   'htn ',
#   'hypercholesterolemia ',
#   'anxiety ',
#   'delirium ',
#   's/p right sided stroke, with dysphasia '],
#  ['scalp laceration ',
#   'status post fall ',
#   'hypertension ',
#   'aortic valve stenosis ',
#   'syncope '],
#  ['primary: respiratory failure ',
#   'secondary: non st-elevation mi, transaminitis, acute renal  ',
#   'failure '],
#  [' lower gi bleeding, nos; likely secondary to manual  ',
#   'disimpaction ',
#   ' 2 cm vaginal abrasion ',
#   'diverticulosis    ',
#   'hypertension   ',
#   'hiatal hernia   ',
#   'increased cholesterol   ',
#   'atrial fibrillation ',
#   'dementia '],
#  ['pneumonia ',
#   'non st elevation myocardial infarction ',
#   'congestive heart failure, ef 15-20% ',
#   'copd ',
#   'hypertension ',
#   'gerd '],
#  ['bilateral pneumonia ',
#   'altered mental status ',
#   'hypoxia ',
#   'dementia ',
#   'copd ',
#   'hypertension '],
#  ['febrile neutropenia ',
#   'pcp [**name initial (pre) 3643**] ',
#   'chronic lymphocytic leukemia ',
#   'hypertension ',
#   '[**doctor last name **] disordered breathing '],
#  [' sepsis ',
#   ' candidemia ',
#   ' thrombus versus fungal vegetation on pacer wire ',
#   ' end stage renal disease ',
#   ' atrial fibrillation ',
#   ' peripheral vascular disease ',
#   ' gi bleed ',
#   ' dementia '],
#  ['seizure with epilepsy ',
#   'swallowing difficulty ',
#   'premature atrial contractions ',
#   'hyponatremia ',
#   'diabetes ',
#   'thrombocytopenia '],
#  ['schizophenia ', 'pulmonary emboli ', 'community acquired pneumonia '],
#  ['metastatic cancer ', 'pericadial effusion ', 'sepsis '],
#  ['expired '],
#  ['delirium secondary to hyponatremia probable secondary to  ',
#   'dehydration ',
#   'l1 vertebral compression fracture  ',
#   'spinal stenosis ',
#   'hypertension ',
#   'hypothyroidism ',
#   'urinary incontinence ',
#   'history of drop attacks ',
#   ' peripheral neuropathy ',
#   'congestive heart failure ',
#   'mitral valve regurgitation ',
#   '1hypotension secondary to overdiuresis '],
#  ['chronic obstructive pulmonary disease exacerbation ',
#   'congestive heart failure '],
#  ['primary: upper gi bleed, pud, anemia ',
#   'secondary: adrenal insufficiency  '],
#  [' gastrointestinal bleed from a dieulafoy lesion ',
#   ' acute myocardial infarction '],
#  ['acquired immune deficiency syndrome ',
#   'adenocarcinoma of lung ',
#   'pulmonary emboli ',
#   'mesenteric ischemia '],
#  ['upper gi bleed ',
#   'secondary diagnoses ',
#   'hepatitis c cirrhosis, genotype 1, vl 335k, on transplant list,  ',
#   '     variceal bleed [**3367-1-20**], 3 band applied ',
#   'hypertension   ',
#   'congestive heart failure   ',
#   'iron deficiency   ',
#   'h/o etoh abuse   ',
#   'depression w/ suicide attempt   ',
#   'gastroesophageal reflux disease   ',
#   'h/o esophageal varices   '],
#  ['hepatic failure from cirrhosis ', 'renal failure '],
#  ['primary:  ',
#   ' st elevation mi ',
#   ' cardiogenic shock ',
#   ' septic shock ',
#   ' three vessel coronary artery disease ',
#   ' congestive heart failure ',
#   ' atrial fibrillation ',
#   ' exacerbation of severe chronic kidney disease '],
#  ['patient expired '],
#  ['diabetic ketoacidosis ',
#   'acute renal failure ',
#   'hypokalemia ',
#   'osteoporosis '],
#  ['ventricular tachycardia  ',
#   'status post ep study without ablation ',
#   'adjustment of pacer (atp) '],
#  ['peripheral vascular disease ',
#   'ischemic colitis ',
#   'respiratory arrest ',
#   'cardiac arrest '],
#  ['left frontal intracranial hemorrhage ', 'h. pylori infection ']]
