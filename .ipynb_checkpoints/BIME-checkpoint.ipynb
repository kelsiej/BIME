# %%
import pandas as pd
import glob
import os 
import re
import itertools
import codecs
from collections import Counter

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', None)

# %%
#get the data and create a dataframe
cwd = os.getcwd()
events = []
os.chdir(cwd + '\\notes')
events = []
#convert all txt files in cwd to df, append to events, then concatenate
for file in glob.glob("*.txt"):
    data = pd.read_csv(file, encoding ='latin1')
    events.append(data)
events = pd.concat(events)
events = events.reset_index()

# %%
#this cell was used to look at the medical data of a patient for my story
# will use 8192
#df_8192 = events.loc[events.SUBJECT_ID.isin([8192])]
#df_8192 = df_8192.reset_index()

#for i in range(len(df_8192)):
#    print(codecs.decode(df_8192.TEXT.loc[i], 'unicode_escape'))

# %%
#filter out rows where the category is not a discharge summary
discharge = events.loc[events.CATEGORY == 'DISCHARGE_SUMMARY'].TEXT.tolist()
#loop through and replace escape characters
for i in range(len(discharge)):
    discharge[i] = discharge[i].replace('\n','newline').replace('\r',' ')

# %%
#only discharge diagnosis is needed so search for the text in between
#discharge diagnoses and discharge condition, then append to a new list
diagnosis_raw = []
for i in discharge:
    if re.search(r'DISCHARGE DIAGNOSES(.*?)DISCHARGE CONDITION', i, re.IGNORECASE):
        diagnosis_raw.append(re.search(r'DISCHARGE DIAGNOSES(.*?)DISCHARGE CONDITION', i, re.IGNORECASE).group(1))
    if re.search(r'DISCHARGE DIAGNOSiS(.*?)DISCHARGE CONDITION', i, re.IGNORECASE):
        diagnosis_raw.append(re.search(r'DISCHARGE DIAGNOSiS(.*?)DISCHARGE CONDITION', i, re.IGNORECASE).group(1))

# %%
#everything between the text newline is an one diagnosis
#save an individuals diagnoses to a temp list, then append that 
# temp list to new list diagnosis
diagnosis = []
for j in diagnosis_raw:   
    start = []
    end = []
    for m in re.finditer('newline', j):
        start.append(m.start())
        end.append(m.end())
    diagnosis_ind = []
    for i in range(len(start)-1):
        diagnosis_ind.append((j[end[i]:start[i+1]]))       
    diagnosis.append(diagnosis_ind)

#some issue I can't figure out, should be a simpler way to do the previous cell
#but skips every other new line :(
#not_working = re.findall(r'newline(.*?)newline', diagnosis_raw[1])

#some lists start with numbers. remove those numbers
for i in range(len(diagnosis)):
    for j in range(len(diagnosis[i])):
        diagnosis[i][j] = diagnosis[i][j].replace('1. ','').replace('2. ','').replace('3. ','').replace('4. ','')\
        .replace('5. ','').replace('6. ','').replace('7. ','').replace('8. ','').replace('9. ','')\
        .replace('10. ','').replace('11. ','')

#turn everything into lowercase for uniformity
for i in range(len(diagnosis)):
    diagnosis[i] = [x.lower() for x in diagnosis[i]]
    
#filter out blank values
for i in range(len(diagnosis)):
    diagnosis[i] = list(filter(None, diagnosis[i]))

# %%
#remove values from list unrelated to a diagnosis
for i in range(len(diagnosis)):
    for j in range(len(diagnosis[i])):
        diagnosis[i][j] = diagnosis[i][j].rstrip()
    if ' ' in diagnosis[i]:
            diagnosis[i].remove(' ')  
    if '' in diagnosis[i]:
        diagnosis[i].remove('')
    if '  ' in diagnosis[i]:
        diagnosis[i].remove('  ') 
    if '   ' in diagnosis[i]:
        diagnosis[i].remove('   ')  
#remove patients that died
    if 'expired' in diagnosis[i]:
            diagnosis[i].remove('expired')

# %%
#if a value starts/ends in punctuation, remove that part
for i in range(len(diagnosis)):
    for j in range(len(diagnosis[i])):
        if diagnosis[i][j].endswith('.'):
            diagnosis[i][j] = diagnosis[i][j][:-1]
        if diagnosis[i][j].endswith(':'):
            diagnosis[i][j] = diagnosis[i][j][:-1]
        if diagnosis[i][j].startswith(' '):
            diagnosis[i][j] = diagnosis[i][j][1:]
#if a value starts/ends with primary/secondary stuff, remove that part           
        if diagnosis[i][j].startswith('primary: '):
            diagnosis[i][j] = diagnosis[i][j][9:]
        if diagnosis[i][j].startswith('primary diagnosis: '):
            diagnosis[i][j] = diagnosis[i][j][19:]
        if diagnosis[i][j].startswith('secondary diagnosis: '):
            diagnosis[i][j] = diagnosis[i][j][21:]
        if diagnosis[i][j].startswith('secondary: '):
            diagnosis[i][j] = diagnosis[i][j][11:]
#also want to get rid of status bit if diagnosis starts with that
        if diagnosis[i][j].startswith('status '):
            diagnosis[i][j] = diagnosis[i][j][7:]
#gi = gastrointestinal, switch it to that
        if 'gi ' in diagnosis[i][j]:
            diagnosis[i][j] = diagnosis[i][j].replace('gi ', 'gastrointestinal ')

# %%
#remove these values from lists, they aren't diagnoses
for i in range(len(diagnosis)):
    diagnosis[i] = list(filter(lambda k:'secondary diagnoses' not in k, diagnosis[i]))
    diagnosis[i]= list(filter(lambda k:'secondary diagnosis' not in k, diagnosis[i]))
    diagnosis[i] = list(filter(lambda k: 'secondary' not in k, diagnosis[i]))
    diagnosis[i] = list(filter(lambda k: 'primary' not in k, diagnosis[i]))
    diagnosis[i] = list(filter(lambda k: 'primary diagnosis' not in k, diagnosis[i]))
    diagnosis[i] = list(filter(lambda k: 'primary diagnoses' not in k, diagnosis[i]))

# %%
#when there is a comma in a diagnosis, it is actually multiple diagnoses. 
#split the string, replace the value with the first split value, then
#append the following values to the list
for i in range(len(diagnosis)):
    for j in range(len(diagnosis[i])):
        if "," in diagnosis[i][j]:
            x = diagnosis[i][j].split(", ")
            diagnosis[i][j] = x[0]
            for k in range(1, len(x)):
                diagnosis[i].append(x[k])

# %%
#repeat this, for unknown reason empty values are still there
for i in range(len(diagnosis)):
    diagnosis[i] = list(filter(None, diagnosis[i]))

# %%
#in this cell I looked up a bunch of terms to find the same 
#diagnoses that was worded differently. In the following cell I will
#change them to the same value.
#I did not get them all, just the most common ones
#example:
for i in range(len(diagnosis)):
    for j in range(len(diagnosis[i])):
        if "kid" in diagnosis[i][j]:
            #I added their location for troubleshooting in previous parts
            print(i)
            print(j)
            print(diagnosis[i][j])
# Out:
# 13
# 4
# chronic kidney disease stage v
# 23
# 5
# chronic kidney disease
# 57
# 6
# exacerbation of severe chronic kidney disease

# %%
#looked up each term shown in cell above, verified they were all the same and in the following cell 
#changed values for uniformity
for i in range(len(diagnosis)):
    for j in range(len(diagnosis[i])):
        if "pneu" in diagnosis[i][j]:
            diagnosis[i][j] = "pneumonia"
        if "heart" in diagnosis[i][j]:
            diagnosis[i][j] = "heart failure"
        if "demen" in diagnosis[i][j]:
            diagnosis[i][j] = "dementia"
        if "del" in diagnosis[i][j]:
            diagnosis[i][j] = "delirium"
        if "renal fail" in diagnosis[i][j]:
            diagnosis[i][j] = "renal failure"
        if "renal disease" in diagnosis[i][j]:
            diagnosis[i][j] = "renal disease"
        if "diab" in diagnosis[i][j]:
            diagnosis[i][j] = "diabetes mellitus"
        if "hemor" in diagnosis[i][j]:
            diagnosis[i][j] = "hemorrhage"
        if "copd" in diagnosis[i][j]:
            diagnosis[i][j] = "chronic obstructive pulmonary disease"
        if "cancer" in diagnosis[i][j]:
            diagnosis[i][j] = "cancer"
        if "pancre" in diagnosis[i][j]:
            diagnosis[i][j] = "pancreatitis"
        if "gastroin" in diagnosis[i][j]:
            diagnosis[i][j] = "gastrointestinal bleed"
        if "stroke" in diagnosis[i][j]:
            diagnosis[i][j] = "stroke"
        if "expi" in diagnosis[i][j]:
            diagnosis[i][j] = "expired"
        if "neuro" in diagnosis[i][j]:
            diagnosis[i][j] = "neuropathy"
        if "fib" in diagnosis[i][j]:
            diagnosis[i][j] = "atrial fibrillation"
        if "depression" in diagnosis[i][j]:
            diagnosis[i][j] = "depression"
        if "hypert" in diagnosis[i][j]:
            diagnosis[i][j] = "hypertension"
        if "htn" in diagnosis[i][j]:
            diagnosis[i][j] = "hypertension"
        if "chol" in diagnosis[i][j]:
            diagnosis[i][j] = "hypercholesterolemia"
        #coronary artery disease = cad
        if "cad" == diagnosis[i][j]:
            diagnosis[i][j] = "coronary artery disease"
        if "artery disease" in diagnosis[i][j]:
            diagnosis[i][j] = "coronary artery disease"

# %%
# here is list of all diagnoses, there still is a lot
# of unstandardized stuff, but for the most part I 
# standardized commonly occuring terms
diagnosis
# Out:
# [['left foot gangrene',
#   'urosepsis',
#   'atrial fibrillation',
#   'esrd/hd',
#   'diabetes mellitus',
#   'mrsa',
#   'depression',
#   'glaucoma'],
#  ['mrsa bacteremia',
#   'pseudomonal lung infection',
#   'cancer',
#   'neuropathy',
#   'chronic obstructive pulmonary disease',
#   'atrial fibrillation',
#   'hypertension',
#   'hypothyroidism',
#   'anemia',
#   'cancer',
#   'neuropathy'],
#  ['death'],
#  ['atrial fibrillation'],
#  ['thoracic aortic aneurysm - s/p endovascular stent',
#   'pneumonia',
#   'emphysema',
#   'lung resection',
#   'nephrectomy',
#   'postop',
#   'chronic obstructive pulmonary disease,',
#   'history of asbestosis versus mesotheilioma - s/p rul',
#   'hypertension',
#   'renal cell carcinoma - s/p',
#   'depression'],
#  ['pancreatitis',
#   'anoxic brain injury',
#   'brain death',
#   'pneumonia',
#   'diabetes mellitus',
#   'hypertension',
#   'coronary artery disease',
#   'blood loss anemia',
#   'respiratory failure'],
#  [],
#  ['cancer'],
#  ['coronary artery disease',
#   'myocardial infarction',
#   'depression',
#   'diabetes mellitus',
#   'chronic back pain',
#   'hypertension',
#   'hypercholesterolemia'],
#  [],
#  ['gastrointestinal bleed',
#   'urinary tract infection',
#   'c difficile infection',
#   'alcoholic cirrhosis',
#   'depression'],
#  ['chf',
#   'pneumonia',
#   'tachycardia of undetermined origin',
#   'renal disease',
#   'hypertension',
#   'dementia'],
#  ['delirium',
#   'dementia',
#   'severe emphysema',
#   'pancreatitis',
#   'atrial fibrillation',
#   'heart failure',
#   'osteoporosis'],
#  ['heart failure',
#   'nstemi',
#   'stroke',
#   'renal failure',
#   'chronic kidney disease stage v',
#   'peripheral vascular disease',
#   'bilateral bka',
#   'diabetes mellitus',
#   'neuropathy',
#   's/p lue fistula [**2770-3-6**]'],
#  ['hemorrhage', 'hemorrhage'],
#  ['pneumonia',
#   'restrictive lung disease',
#   'hypertension',
#   's/p pulmonary embolus',
#   'glaucoma'],
#  ['metastatic breast ca', 'hemoptysis', 'gastric ulcer'],
#  ['stroke',
#   '-grade i splenic laceration',
#   'pneumonia',
#   '-t12 wedge compression fracture',
#   '-asymptomatic high-grade left internal carotid artery stenosis'],
#  ['chf', 'respiratory failure', 'renal failure', 'delirium', 'hypotension'],
#  ['stroke'],
#  ['polypectomy',
#   'intervention/injection',
#   'hypertension',
#   'hypothyroidism',
#   'hypertension',
#   'hypercholesterolemia',
#   'cancer',
#   'mitral regurgitation',
#   'tricuspid regurgitation',
#   'diastolic dysfunction',
#   'post colonoscopy and',
#   'cauterization of the bleeding lesion'],
#  ['clostridium difficile colitis'],
#  ['cancer'],
#  ['heart failure',
#   'aortic stenosis',
#   'mitral stenosis',
#   'possible chronic obstructive lung disease',
#   'coronary artery disease',
#   'chronic kidney disease',
#   'depression',
#   'diabetes mellitus'],
#  ['left hip fracture s/p orif w/ subsequent hematoma',
#   'nstemi',
#   'heart failure',
#   'atrial fibrillation',
#   'lv apical thrombus',
#   'generalized tonic-clonic seizure - left sided [**doctor last name 1210**]',
#   'paralysis',
#   'pneumonia',
#   'delirium',
#   'malnutrition - moderate degree',
#   'dementia',
#   'normal pressure hydrocephalus s/p vp shunt',
#   'coronary artery disease',
#   'ischemic cardiomyopathy 4+ mitral regurgitation'],
#  ['hemorrhage',
#   'hemorrhage',
#   'pneumonia',
#   'hypertension',
#   'atrial fibrillation',
#   'hypokalemia'],
#  ['ventricular tachycardia',
#   'cardiac arrest',
#   'atrial fibrillation',
#   'respiratory failure',
#   'hemodialysis line infection',
#   'pneumonia',
#   'renal failure',
#   'heart failure',
#   'coronary artery disease',
#   'peripheral vascular disease',
#   'diabetes mellitus',
#   'stroke',
#   'atrial fibrillation'],
#  ['gastrointestinal bleed',
#   'hypernatremia',
#   'parotid abscesses',
#   'uti',
#   'left arm mrsa swab',
#   'hypertension',
#   'chf',
#   'chronic obstructive pulmonary disease'],
#  ['1) mva resulting in traumatic head injury with subarachnoid',
#   'hemorrhage',
#   'superior sagittal sinus from depressed right-sided high',
#   'parietal/high frontal skull fracture crossing midline',
#   '      --s/p right-sided hemicraniectomy',
#   'hematoma',
#   '2) fevers - query drug hypersensitivity',
#   '6) moderate malnutrition',
#   '7) anemia of inflammation',
#   'mild blood loss - occult blood positive stools',
#   'hypertension',
#   '9) elevation of alpha-1-antitrypsin - query significance - would',
#   'repeat when acute inflammatory state subsides',
#   'hemorrhage',
#   'hemorrhage',
#   'lacerated',
#   'evacuation of',
#   'repair of sinus',
#   'no evidence for hemolysis',
#   'with some'],
#  ['non-small cell lung carcinoma',
#   'massive hemoptysis',
#   'hairy cell leukemia',
#   'cancer'],
#  ['pneumonia',
#   'pneumonia',
#   'chronic obstructive pulmonary disease',
#   'pancreatitis'],
#  ['pancreatitis',
#   'bilateral pleural effusions',
#   'tongue mass',
#   'pneumonia',
#   'anemia of chronic disease'],
#  ['heptic encephalopathy',
#   'anemia',
#   'melena',
#   'varices of the esophagus',
#   'cirrhosis [**12-30**] to hep c (on tx list)',
#   'osteopenia',
#   'reflex sympathetic dystrophy',
#   'hypertension',
#   'echo',
#   "mva in '[**80**] with head injury"],
#  ['aortic occlusion',
#   'axillary bifemoral bypass graft with ptfe',
#   'ischemic colon',
#   'respiratory failure',
#   'cardiac arrest',
#   'metabolic acidosis',
#   'abdominal compartment syndrome',
#   'pleural effusion',
#   'shock',
#   'aaa',
#   'mesenteric ischemia',
#   'exploratory laparotomy',
#   'coagulopathy',
#   'renal failure'],
#  ['biliateral supracondylar femural fractures',
#   'exacerbation',
#   'anemia',
#   'chronic obstructive pulmonary disease',
#   'chronic lower back pain',
#   'pneumonia',
#   'chronic obstructive pulmonary disease',
#   'coronary artery disease',
#   'osteoperosis,',
#   'migraines',
#   'depression'],
#  ['gastrointestinal bleed',
#   'cancer',
#   'hypertension',
#   '-hypothyroidism',
#   'diabetes mellitus',
#   'likely from gastric varices'],
#  ['esophageal and gastric variceal bleeding,',
#   'active substance abuse',
#   'patent tips',
#   'hepatitis c cirrhosis',
#   'failed liver transplant,',
#   'pancytopenia'],
#  ['cancer', 'cancer'],
#  ['gastrointestinal bleed',
#   '----',
#   'hypertension',
#   'hypercholesterolemia',
#   'anxiety',
#   'delirium',
#   'stroke',
#   'with dysphasia'],
#  ['scalp laceration',
#   'post fall',
#   'hypertension',
#   'aortic valve stenosis',
#   'syncope'],
#  ['respiratory failure',
#   'non st-elevation mi',
#   'failure',
#   'transaminitis',
#   'acute renal'],
#  ['disimpaction',
#   '2 cm vaginal abrasion',
#   'diverticulosis',
#   'hypertension',
#   'hiatal hernia',
#   'hypercholesterolemia',
#   'atrial fibrillation',
#   'dementia'],
#  ['pneumonia',
#   'non st elevation myocardial infarction',
#   'heart failure',
#   'chronic obstructive pulmonary disease',
#   'hypertension',
#   'gerd',
#   'ef 15-20%'],
#  ['pneumonia',
#   'altered mental status',
#   'hypoxia',
#   'dementia',
#   'chronic obstructive pulmonary disease',
#   'hypertension'],
#  ['febrile neutropenia',
#   'pcp [**name initial (pre) 3643**]',
#   'chronic lymphocytic leukemia',
#   'hypertension',
#   '[**doctor last name **] disordered breathing'],
#  ['sepsis',
#   'candidemia',
#   'thrombus versus fungal vegetation on pacer wire',
#   'renal disease',
#   'atrial fibrillation',
#   'peripheral vascular disease',
#   'gastrointestinal bleed',
#   'dementia'],
#  ['seizure with epilepsy',
#   'swallowing difficulty',
#   'premature atrial contractions',
#   'hyponatremia',
#   'diabetes mellitus',
#   'thrombocytopenia'],
#  ['schizophenia', 'pulmonary emboli', 'pneumonia'],
#  ['cancer', 'pericadial effusion', 'sepsis'],
#  [],
#  ['dehydration',
#   'l1 vertebral compression fracture',
#   'spinal stenosis',
#   'hypertension',
#   'hypothyroidism',
#   'urinary incontinence',
#   'history of drop attacks',
#   'neuropathy',
#   'heart failure',
#   'mitral valve regurgitation'],
#  ['chronic obstructive pulmonary disease exacerbation', 'heart failure'],
#  ['gastrointestinal bleed', 'adrenal insufficiency', 'pud', 'anemia'],
#  ['gastrointestinal bleed', 'acute myocardial infarction'],
#  ['acquired immune deficiency syndrome',
#   'adenocarcinoma of lung',
#   'pulmonary emboli',
#   'mesenteric ischemia'],
#  ['gastrointestinal bleed',
#   'hepatitis c cirrhosis',
#   '   variceal bleed [**3367-1-20**]',
#   'hypertension',
#   'heart failure',
#   'iron deficiency',
#   'h/o etoh abuse',
#   'depression',
#   'gastroesophageal reflux disease',
#   'h/o esophageal varices',
#   'genotype 1',
#   'vl 335k',
#   'on transplant list,',
#   '3 band applied'],
#  ['hepatic failure from cirrhosis', 'renal failure'],
#  ['st elevation mi',
#   'cardiogenic shock',
#   'septic shock',
#   'coronary artery disease',
#   'heart failure',
#   'atrial fibrillation',
#   'exacerbation of severe chronic kidney disease'],
#  [],
#  ['diabetes mellitus', 'renal failure', 'hypokalemia', 'osteoporosis'],
#  ['ventricular tachycardia',
#   'post ep study without ablation',
#   'adjustment of pacer (atp)'],
#  ['peripheral vascular disease',
#   'ischemic colitis',
#   'respiratory arrest',
#   'cardiac arrest'],
#  ['hemorrhage', 'h. pylori infection']]

# %%
#diagnosis was a list of lists - combine them into one list
diagnosis_all = list(itertools.chain.from_iterable(diagnosis))

# %%
#count how many times a term appears, find top 
#10 most common
count = Counter(diagnosis_all)
common_diag = count.most_common(10)

# %%
#probably a bad way to do it, but common_diag was a list of each term.
#I only want it as a string of all diagnoses and the frequency they 
#appeared so I did that here
common_diagnoses = []
for i in range(len(common_diag)):
    common_diagnoses.append(common_diag[i][0] + ': ' + str(common_diag[i][1]))
comb = ''
for i in common_diagnoses:
    comb = comb + i + ', '

#since I want to create a table, I need the string as a list
common_diagnoses = []
common_diagnoses.append(comb)

# %%
#get average diagnoses
diagnosis_avg = []
for i in diagnosis:
    diagnosis_avg.append(len(i))
average_diagnoses = sum(diagnosis_avg)/len(diagnosis_avg)

# %%
#get how many patients have diagnoses
patients_w_diagnoses = len(diagnosis)

# %%
#create a table to display the information by using a dataframe
data = {'Common Discharge Diagnoses ': common_diagnoses, 'Patients with Disharge Diagnoses': \
        patients_w_diagnoses, ' Avg. # of Diagnoses per Patient': average_diagnoses}
discharge_summary = pd.DataFrame.from_dict(data)

# %%
#and done
discharge_summary
# Out:
#                                                                                                                                                                                           Common Discharge Diagnoses   \
# 0  hypertension: 21, pneumonia: 15, atrial fibrillation: 11, cancer: 10, heart failure: 10, diabetes mellitus: 9, gastrointestinal bleed: 8, hemorrhage: 8, depression: 7, chronic obstructive pulmonary disease: 7,
#
#    Patients with Disharge Diagnoses   Avg. # of Diagnoses per Patient
# 0                                63                          5.793651
